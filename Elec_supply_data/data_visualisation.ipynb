# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv("data/fes2024_es1_v002.csv")
df
# Out:
#       Connection              Pathway       Variable   Category  \
# 0    Distributed  Electric Engagement  Capacity (MW)  Renewable
# 1    Distributed  Electric Engagement  Capacity (MW)  Renewable
# 2    Distributed  Electric Engagement  Capacity (MW)  Renewable
# 3    Distributed  Electric Engagement  Capacity (MW)  Renewable
# 4    Distributed  Electric Engagement  Capacity (MW)  Renewable
# ..           ...                  ...            ...        ...
# 609         Both  Electric Engagement    Demand (MW)     Demand
# 610         Both  Holistic Transition    Demand (MW)     Demand
# 611         Both   Hydrogen Evolution    Demand (MW)     Demand
# 612         Both       Counterfactual    Demand (MW)     Demand
# 613         Both   Five Year Forecast    Demand (MW)     Demand
#
#                                      Type        SubType         2023  \
# 0                                 Biomass        Biomass    735.00000
# ...

# %%
df.columns
# Out:
# Index(['Connection', 'Pathway', 'Variable', 'Category', 'Type', 'SubType',
#        '2023', '2024', '2025', '2026', '2027', '2028', '2029', '2030', '2031',
#        '2032', '2033', '2034', '2035', '2036', '2037', '2038', '2039', '2040',
#        '2041', '2042', '2043', '2044', '2045', '2046', '2047', '2048', '2049',
#        '2050'],
#       dtype='object')

# %%
for name in df.columns[:5]:
    print(name, ":", set(df[name]))
# Out:
# Connection : {'Transmission', 'Distributed', 'Non-Networked', 'Both'}
# Pathway : {'Electric Engagement', 'Hydrogen Evolution', 'Holistic Transition', 'Five Year Forecast', 'Counterfactual'}
# Variable : {'Available DSR (MW)', 'Curtailment (TWh)', 'CO2 Intensity of Generation (gCO2/kWh)', 'Consumption (TWh)', 'Generation (TWh)', 'Import (TWh)', 'Capacity (MW)', 'Netflows (TWh)', 'Export (TWh)', 'Demand Reduction (TWh)', 'Demand (TWh)', 'Curtailment including DACCS (TWh)', 'Demand (MW)', 'Storage Capacity (GWh)'}
# Category : {'Thermal', 'Interconnectors', 'Storage', 'CO2', 'Renewables including negative emissions', 'Renewable', 'Low Carbon', 'Demand', 'Negative emissions'}
# ...

# %%
df.loc[(df["Connection"] == "Transmission") & (df["Pathway"] == "Electric Engagement")]
# Out:
#        Connection              Pathway                Variable  \
# 76   Transmission  Electric Engagement           Capacity (MW)
# 77   Transmission  Electric Engagement           Capacity (MW)
# 78   Transmission  Electric Engagement           Capacity (MW)
# 79   Transmission  Electric Engagement           Capacity (MW)
# 80   Transmission  Electric Engagement           Capacity (MW)
# 81   Transmission  Electric Engagement           Capacity (MW)
# 82   Transmission  Electric Engagement           Capacity (MW)
# 83   Transmission  Electric Engagement           Capacity (MW)
# 84   Transmission  Electric Engagement           Capacity (MW)
# 85   Transmission  Electric Engagement           Capacity (MW)
# 86   Transmission  Electric Engagement           Capacity (MW)
# 87   Transmission  Electric Engagement           Capacity (MW)
# 88   Transmission  Electric Engagement           Capacity (MW)
# 89   Transmission  Electric Engagement           Capacity (MW)
# ...
